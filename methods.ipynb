# %%
import numpy as np

# %% [markdown]
# # Metoda Eulera

# %% [markdown]
# # Metody różnicowe

# %% [markdown]
# # Ogólny wzór różnicowy

# %% [markdown]
# # Równanie dla błędu

# %% [markdown]
# # Stabilność i zbieżność

# %% [markdown]
# # Metody Rungego-Kutt
# ]
