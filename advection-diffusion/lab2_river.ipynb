# %%
import numpy as np

# %%
N=10
n = 1000
c = np.zeros((n))
Ca = U * dt / dx
Cd = D * dt /dx**2

for j in range(2,N-2):
    A = (Cd*(1-Ca) - Ca/6 * (Ca^2-3*Ca+2))
    B = Cd*(2-3*Ca)-Ca/2*(Ca**2-2*Ca-1)
    C = Cd*(1-3*Ca)-Ca/2*(Ca**2-Ca-2)
    D = Cd*Ca+Ca/6*(Ca**2-1)
    c[j]=c[j-1] + A*c[j+1] - B*c[j] + C*c[j-1] + D*c[j-2]
